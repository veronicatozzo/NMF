# %%
import numpy as np
import pandas as pd

from importlib import reload
import netanalytics.inference; reload(netanalytics.inference)
from netanalytics.inference import mutual_rank_graph

# %%
X = pd.read_csv("/Users/veronica/Dropbox (DIBRIS)/project_UCL/data/BRCA_gene_expression_subset.csv", index_col=0, header=None)

# %%
X
# Out:
#           1          2         3         4         5         6         7     \
# 0
# 0     4.087463  14.778026  5.523562  1.000000  0.000000  0.000000  0.000000
# 1     5.857981  15.538098  6.700440  4.247928  2.584963  0.000000  0.000000
# 2     4.087463  14.798877  5.169925  3.700440  2.584963  1.584963  0.000000
# 3     4.754888  15.992983  6.375039  4.169925  0.000000  3.906891  0.000000
# 4     3.000000  13.704984  6.768184  3.700440  1.000000  0.000000  0.000000
# 5     5.044394  16.205373  6.658211  5.129283  2.584963  1.584963  0.000000
# 6     4.392317  14.779206  5.727920  2.321928  2.000000  0.000000  0.000000
# 7     6.459432  15.408164  6.066089  3.906891  0.000000  1.584963  0.000000
# 8     5.209453  15.403212  6.266787  1.584963  2.807355  5.930737  1.000000
# 9     4.754888  13.776947  4.857981  1.584963  0.000000  0.000000  0.000000
# 10    4.700440  17.988357  6.918863  6.584963  0.000000  3.906891  0.000000
# ...

# %%
res = mutual_rank_graph(X)
# Out:
# /Users/veronica/miniconda3/envs/py36/lib/python3.6/site-packages/scipy-1.1.0-py3.6-macosx-10.7-x86_64.egg/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-bdf1528e4e90> in <module>()
# ----> 1 res = mutual_rank_graph(X)
#
# ~/Desktop/git_repos/netanalytics/netanalytics/inference.py in mutual_rank_graph(X, threshold)
#      25     """
#      26
# ---> 27     pc = pairwise_kernels(X.T, metric=pearson_correlation)
#      28     pc -= np.diag(np.diag(pc))
#      29     mr_r = np.zeros_like(pc)
#
# ~/Desktop/git_repos/scikit-learn/sklearn/metrics/pairwise.py in pairwise_kernels(X, Y, metric, filter_params, n_jobs, **kwds)
#    1557         raise ValueError("Unknown kernel %r" % metric)
#    1558
# ...

# %%
prova = np.random.rand(10)

# %%
np.sort(prova)
# Out:
# array([0.00097942, 0.04596869, 0.23838322, 0.23871931, 0.28307024,
#        0.32230905, 0.42804539, 0.68203174, 0.76481762, 0.83713463])

# %%
np.argsort(prova)
# Out:
# array([9, 4, 3, 5, 2, 8, 6, 0, 1, 7])

# %%
prova[np.argsort(prova)]
# Out:
# array([0.00097942, 0.04596869, 0.23838322, 0.23871931, 0.28307024,
#        0.32230905, 0.42804539, 0.68203174, 0.76481762, 0.83713463])

# %%
i = np.arange(1, 11)
i[np.argsort(prova)[::-1]]
# Out:
# array([ 8,  2,  1,  7,  9,  3,  6,  4,  5, 10])
