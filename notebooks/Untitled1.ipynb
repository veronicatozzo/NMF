# %%
import numpy as np
import pandas as pd
import pickle as pkl

# %%
rr = pd.read_csv("/Users/veronica/Dropbox (DIBRIS)/project_ucl/networks/_aracne_a.csv", index_col=0)

# %%
genes = [str(g).lower() for g in rr.index.values]
genes
# Out:
# ['a1bg',
#  'a2m',
#  'a2m.as1',
#  'a2mp1',
#  'a4gnt',
#  'aadac',
#  'aadacl2',
#  'aadacl2.as1',
#  'aadacl3',
#  'aadacl4',
#  'aadacp1',
#  'aagab',
#  'aass',
#  'aatf',
#  'abca1',
#  'abca10',
#  'abca5',
#  'abca6',
#  'abca8',
#  'abca9',
#  'abca9.as1',
#  'abcb1',
#  'abcb11',
#  'abcb5',
#  'abcb8',
#  'abcb9',
#  'abcc5',
#  'abcc6',
#  'abcc6p1',
#  'abcc9',
#  'abcd2',
#  'abcd4',
#  'abcf3',
#  'abcg2',
#  'abcg8',
#  'abhd1',
#  'abhd11',
#  'abhd12',
#  'abhd14b',
#  'abhd15',
#  'abhd17ap7',
#  'abhd17ap9',
#  'abhd17c',
#  'abhd5',
#  'abhd6',
#  'abi3bp',
#  'ablim1',
#  'ablim3',
#  'abo',
#  'abra',
#  'abracl',
#  'abraxas1',
#  'abtb1',
#  'acaa2',
#  'acacb',
#  'acad11',
#  'acadl',
#  'acadm',
#  'acads',
#  'acadvl',
#  'acan',
#  'acap3',
#  'acat1',
#  'acbd3',
#  'acbd6',
#  'accs',
#  'ace2',
#  'ackr1',
#  'ackr2',
#  'ackr3',
#  'ackr4',
#  'aco1',
#  'acot7',
#  'acot8',
#  'acp1',
#  'acr',
#  'acrv1',
#  'acsbg2',
#  'acsl1',
#  'acsl4',
# ...

# %%
with open("/Users/veronica/Dropbox (DIBRIS)/project_ucl/networks/list_genes_networks_big.pkl", 'wb') as f :
    pkl.dump(genes, f, protocol=2)
